# %%
# SLNP

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage 

llm = ChatOpenAI(model = "gpt-4o-mini", openai_api_key = OPENAI_API_KEY  , temperature = 0.7, max_tokens = 512)

while True:
    user_input = input("You:")
    response = llm.invoke([HumanMessage(content=user_input)])
    print(f"AI: {response.content}")
# Out:
# You: I want to open an Indian restaurant. Could you suggest me some names?
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[33], line 8
#       6 while True:
#       7     user_input = input("You:")
# ----> 8     response = llm.invoke([HumanMessage(content=user_input)])
#       9     print(f"AI: {response.content}")
#
# File ~\anaconda3\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)
#     447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
# ...

# %% [markdown]
# New OpenAI accounts require card details. Therefore there is 0 limit on the new accounts. Better way is to go for community editions.

# %%
#!pip install langchain langchain-community langchain-core
# Out:
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
# ...

# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.messages import HumanMessage

llm = ChatOllama(
    model = "llama3", 
    temperature = 0.7
)

while True:
    user_input = input("You: ")
    response = llm.invoke([HumanMessage(content=user_input)])
    print(f"AI: {response.content")
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_18000\103765528.py:4: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm = ChatOllama(
# You:  I want to open an Indian Restaurant. Can you suggest some names?
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
# ...
